# %% [markdown]
# <a href="https://colab.research.google.com/github/demsaid400-cpu/DI-BOOTCAMP/blob/main/Week4/Day1/ExercisesXP_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercises XP: Student Notebook
#
# For each exercise, the **Instructions** from the plateform are guided, and the **Guidance** explains exactly what you must do to complete the task.

# %% [markdown]
# ## What you will learn
# - How to clearly define and articulate a machine learning problem statement.
#
# - The process of data collection, including identifying relevant data types and potential data sources.
# Skills in feature selection and justification for machine learning models, particularly in the context of loan default prediction.
#
# - Understanding of different types of machine learning models and their suitability for various real-world scenarios.
#
# - Techniques and strategies for evaluating the performance of different machine learning models, including choosing appropriate metrics and understanding their implications.

# %% [markdown]
# ## What you will create
# - A detailed problem statement and data collection plan for a loan default prediction project, including identification of key data types and sources.
# - A comprehensive feature selection analysis for a hypothetical loan default prediction dataset.
# - A theoretical evaluation strategy for three different types of machine learning models, addressing the unique challenges and metrics relevant to each model type.
# - Thoughtful analyses and justifications for choosing specific machine learning approaches for varied scenarios such as stock price prediction, library organization, and robot navigation.
# - A document or presentation that showcases your understanding and approach to evaluating and optimizing machine learning models in diverse contexts.

# %% [markdown]
# ## 🌟 Exercise 1 : Defining the Problem and Data Collection for Loan Default Prediction
#
# ### Instructions
# - Write a clear problem statement for predicting loan defaults.
# - Identify and list the types of data you would need for this project (e.g., personal details of applicants, credit scores, loan amounts, repayment history).
# - Discuss the sources where you can collect this data (e.g., financial institution’s internal records, credit bureaus).
#
# **Expected Output:** A document detailing the problem statement and a comprehensive plan for data collection, including data types and sources.

# %% [markdown]
# ### Guidance
# - Please write your answer as a short document. Begin by stating the prediction objective in a complete sentence that names the target variable and the decision it will support. Then, describe the data types you would collect in complete sentences. For each data type, explain in one sentence why it could help predict loan defaults.
#
# - After that, name realistic data sources in complete sentences, and briefly describe how you would obtain or integrate each source.
#
# - Finally, include one paragraph that explains risks and constraints such as privacy, regulation, data quality, sampling bias, and governance.

# %% [markdown]
# #Your answer
# To-Do:
#
# Les institutions financières accordent quotidiennement des prêts à des particuliers et à des entreprises. Cependant, certains emprunteurs ne respectent pas leurs obligations de remboursement, ce qui entraîne des pertes financières importantes pour les prêteurs. Afin de réduire ce risque, il est nécessaire de développer un système capable d’identifier à l’avance les clients susceptibles de faire défaut sur leur prêt.
#
# L’objectif de ce projet est de construire un modèle d’apprentissage automatique permettant de prédire la probabilité qu’un emprunteur fasse défaut de paiement. Cette prédiction aidera les banques à prendre des décisions plus éclairées concernant l’approbation des prêts, la fixation des taux d’intérêt et la gestion globale des risques.
#
# D’un point de vue Machine Learning, il s’agit d’un problème de classification binaire :
#
# * Classe 0 : L’emprunteur rembourse correctement son prêt.
# * Classe 1 : L’emprunteur fait défaut de paiement.
#
# Types de données nécessaires
#
# Pour construire un modèle performant, plusieurs catégories de données doivent être collectées :
#
# 1. Informations démographiques
#
# * Âge
# * Sexe
# * Situation matrimoniale
# * Niveau d’éducation
# * Nombre de personnes à charge
#
# Ces variables permettent de mieux comprendre le profil général de l’emprunteur.
#
# 2. Informations financières
#
# * Revenu mensuel
# * Revenus du co-emprunteur
# * Dépenses mensuelles
# * Ratio dette/revenu
# * Épargne disponible
#
# Ces données permettent d’évaluer la capacité réelle de remboursement.
#
# 3. Informations sur le prêt
#
# * Montant du prêt
# * Durée du prêt
# * Taux d’intérêt
# * Type de prêt
# * Objet du financement
#
# Ces caractéristiques influencent directement le niveau de risque associé au prêt.
#
# 4. Historique de crédit
#
# * Score de crédit
# * Nombre de prêts antérieurs
# * Retards de paiement précédents
# * Historique des remboursements
# * Nombre de défauts passés
#
# L’historique de crédit constitue généralement l’un des meilleurs indicateurs du comportement futur d’un emprunteur.
#
# 5. Données comportementales
#
# * Activité bancaire
# * Fréquence des transactions
# * Utilisation des cartes de crédit
# * Solde moyen des comptes
#
# Ces données fournissent des informations supplémentaires sur la stabilité financière du client.
#
# Sources de données
#
# Sources internes
#
# Les banques disposent généralement de nombreuses données historiques :
#
# * Bases de données clients
# * Historique des prêts accordés
# * Transactions bancaires
# * Dossiers de remboursement
#
# Sources externes
#
# Des données complémentaires peuvent être obtenues auprès de :
#
# * Bureaux de crédit
# * Agences gouvernementales
# * Organismes de notation financière
# * Bases de données économiques publiques
#
# Plan de collecte des données
#
# Le processus de collecte des données suivra les étapes suivantes :
#
# 1. Identification des sources de données pertinentes.
# 2. Vérification de la conformité réglementaire.
# 3. Extraction des données historiques.
# 4. Nettoyage et validation des données.
# 5. Traitement des valeurs manquantes.
# 6. Fusion des différentes sources.
# 7. Anonymisation des données sensibles.
# 8. Stockage sécurisé des données.
# 9. Préparation pour l’entraînement du modèle.
#
# Défis potentiels
#
# Plusieurs difficultés peuvent apparaître :
#
# * Données manquantes ou incomplètes.
# * Déséquilibre entre les classes.
# * Biais dans les données historiques.
# * Contraintes liées à la confidentialité des données.

# %% [markdown]
# ## 🌟 Exercise 2 : Feature Selection and Model Choice for Loan Default Prediction
#
# ### Instructions
# From this dataset, identify which features might be most relevant for predicting loan defaults.
# Justify your choice of features.

# %% [markdown]
# ### Guidance
# - First, identify the features that you believe are most relevant, and write their names in a sentence.
# Then, provide a justification in complete sentences that explains how each selected feature relates to the likelihood of default.
#
# - If you decide to exclude common features, write one sentence for each excluded feature to explain why it is not appropriate in this context.
#
# - Conclude with two complete sentences that explain how you would encode categorical features and how you would impute missing values.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It provides a simple template you can modify while writing your justification.

import pandas as pd

# This placeholder DataFrame allows the cell to run even if you did not load a dataset yet.
example_columns = [
    "age","employment_length","annual_income","credit_score","loan_amount","interest_rate",
    "debt_to_income","num_delinquencies","num_open_accounts","total_utilization","home_ownership",
    "purpose","term","application_type","state","zip_code"
]
df = pd.DataFrame(columns=example_columns)

# Please replace this list with the actual columns that you select.
selected_features = [
    # e.g., "credit_score","debt_to_income","annual_income","loan_amount","interest_rate",
    # "employment_length","num_delinquencies","total_utilization"
]

print("You will now justify the selected features in complete sentences below.")
# Out:
# You will now justify the selected features in complete sentences below.

# %% [markdown]
# # My answer
#
# To-Do: Caractéristiques les plus pertinentes
#
# Après analyse d’un ensemble de données de prédiction de prêt, les variables suivantes semblent particulièrement importantes :
#
# Credit_History
#
# Cette variable représente l’historique de remboursement de l’emprunteur. Elle est généralement considérée comme le facteur prédictif le plus important. Un individu ayant déjà rencontré des problèmes de remboursement présente un risque plus élevé de défaut futur.
#
# ApplicantIncome
#
# Le revenu principal du demandeur reflète sa capacité financière à rembourser son prêt. Plus le revenu est élevé, plus le risque de défaut est généralement faible.
#
# CoapplicantIncome
#
# Le revenu du co-emprunteur contribue également à la capacité globale de remboursement et peut réduire le risque.
#
# LoanAmount
#
# Le montant du prêt influence directement le niveau de risque. Les prêts plus importants sont souvent associés à une probabilité de défaut plus élevée.
#
# Loan_Amount_Term
#
# La durée du prêt détermine le montant des mensualités et la période d’exposition au risque.
#
# Debt-to-Income Ratio
#
# Ce ratio mesure la part du revenu consacrée au remboursement des dettes. Un ratio élevé indique souvent une situation financière plus fragile.
#
# Education
#
# Le niveau d’éducation peut être corrélé à la stabilité de l’emploi et au niveau de revenu.
#
# Property_Area
#
# La zone géographique peut refléter certaines conditions économiques ou opportunités d’emploi.
#
# Justification des caractéristiques
#
# Ces variables ont été sélectionnées car elles influencent directement la capacité et la volonté de remboursement de l’emprunteur.
#
# Pour confirmer leur pertinence, plusieurs méthodes de sélection peuvent être utilisées :
#
# * Analyse de corrélation
# * Importance des variables dans Random Forest
# * Information Gain
# * Recursive Feature Elimination (RFE)
#
# L’utilisation de ces techniques permet d’éliminer les variables peu informatives et d’améliorer les performances du modèle.

# %% [markdown]
# ## 🌟 Exercise 3 : Training, Evaluating, and Optimizing the Model
#
# ### Instructions
# Which model(s) would you pick for a Loan Prediction ?
# Outline the steps to evaluate the model’s performance, mentioning specific metrics that would be relevant to evaluate the model.

# %% [markdown]
# ### Guidance
# - Begin by naming one or two candidate models in a complete sentence and explain why each model is suitable for this problem.
#
# - Next, describe an evaluation plan in complete sentences that covers the data split, the cross-validation strategy, the metrics you will report, and how you will choose a decision threshold.
#
# - Then, explain in complete sentences how you will address class imbalance using stratification, class weights, or resampling.
#
# - Finally, state in one or two complete sentences how you would iterate on hyperparameters to improve performance while avoiding data leakage.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It demonstrates standard classification metrics for binary loan default prediction.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, confusion_matrix, classification_report

# Please replace these placeholders with your true labels and predicted probabilities.
y_true = [0,1,0,1,0,0,1,0,1,0]            # placeholder labels
y_pred_proba = [0.05,0.80,0.10,0.65,0.20,0.15,0.70,0.30,0.85,0.25]  # placeholder probabilities

# You should set a decision threshold that reflects the precision–recall trade-off for your business case.
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred, zero_division=0))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0
#
# Confusion matrix:
#  [[6 0]
#  [0 4]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %% [markdown]
# # Your answer
# To-Do: Modèles choisis
#
# Régression Logistique
#
# La régression logistique constitue un excellent modèle de référence pour les problèmes de classification binaire.
#
# Avantages :
#
# * Facile à interpréter.
# * Rapide à entraîner.
# * Fournit des probabilités de défaut.
#
# Limites :
#
# * Difficulté à modéliser des relations complexes.
#
# Random Forest
#
# Random Forest combine plusieurs arbres de décision afin d’améliorer la précision.
#
# Avantages :
#
# * Gère les relations non linéaires.
# * Résistant au bruit.
# * Réduit le surapprentissage.
#
# Limites :
#
# * Moins interprétable.
#
# XGBoost
#
# XGBoost est souvent utilisé dans les applications financières grâce à ses performances élevées.
#
# Avantages :
#
# * Excellente précision.
# * Bonne gestion des données complexes.
# * Gestion efficace des valeurs manquantes.
#
# Limites :
#
# * Paramétrage plus complexe.
# * Temps d’entraînement plus important.
#
# Évaluation du modèle
#
# Division des données
#
# * 80 % pour l’entraînement
# * 20 % pour les tests
#
# Validation croisée
#
# L’utilisation de la validation croisée K-Fold permet d’obtenir une estimation plus fiable des performances.
#
# Métriques de performance
#
# Accuracy
#
# Mesure la proportion totale de prédictions correctes.
#
# Precision
#
# Indique la proportion de défauts prédits qui sont réellement des défauts.
#
# Recall
#
# Mesure la capacité du modèle à détecter les véritables défauts.
#
# Dans le contexte bancaire, cette métrique est particulièrement importante car manquer un client à risque peut entraîner des pertes importantes.
#
# F1-Score
#
# Combine précision et rappel dans une seule mesure.
#
# AUC-ROC
#
# Évalue la capacité du modèle à distinguer les emprunteurs à risque des emprunteurs fiables.
#
# Optimisation
#
# Les performances peuvent être améliorées grâce à :
#
# * Grid Search
# * Random Search
# * Ajustement des hyperparamètres
# * Sélection avancée des variables

# %% [markdown]
# ## 🌟 Exercise 4 : Designing Machine Learning Solutions for Specific Problems
#
# ### Instructions
# For each of these scenario, decide which type of machine learning would be most suitable. Explain.
#
# Predicting Stock Prices : predict future prices
# Organizing a Library of Books : group books into genres or categories based on similarities.
# Program a robot to navigate and find the shortest path in a maze.

# %% [markdown]
# ### Guidance
# Please identify the appropriate machine learning paradigm for each scenario in complete sentences and justify your choice.
#
# For each scenario, write one complete sentence that describes the input data, one complete sentence that describes the output, and one complete sentence that describes the learning signal or objective.

# %% [markdown]
# Prévision des cours des actions
#
# Pour prédire les prix futurs des actions, l’approche la plus adaptée est l’apprentissage supervisé.
#
# Les données historiques fournissent des exemples de prix passés permettant au modèle d’apprendre les tendances du marché.
#
# Modèles possibles :
#
# * Régression linéaire
# * Random Forest Regressor
# * Réseaux de neurones LSTM
#
# Les LSTM sont particulièrement efficaces pour capturer les dépendances temporelles dans les séries chronologiques financières.
#
# 2. Organisation d’une bibliothèque
#
# Pour regrouper automatiquement les livres selon leurs similitudes, l’apprentissage non supervisé est le plus approprié.
#
# Aucune catégorie prédéfinie n’est nécessaire ; le système découvre lui-même les groupes naturels.
#
# Algorithmes possibles :
#
# * K-Means
# * Clustering hiérarchique
# * DBSCAN
#
# Cette approche permet d’organiser efficacement de grandes collections de livres.
#
# 3. Navigation d’un robot dans un labyrinthe
#
# La navigation autonome relève de l’apprentissage par renforcement.
#
# Le robot interagit avec son environnement et apprend progressivement grâce à un système de récompenses.
#
# Exemples :
#
# * Récompense positive lorsqu’il atteint la sortie.
# * Pénalité lorsqu’il rencontre un obstacle.
#
# Algorithmes possibles :
#
# * Q-Learning
# * SARSA
# * Deep Q-Network (DQN)
#
# Cette approche permet au robot d’améliorer progressivement sa stratégie.

# %% [markdown]
# ## 🌟 Exercise 5 : Designing an Evaluation Strategy for Different ML Models
#
# ### Instructions
# - Select three types of machine learning models: one from supervised learning (e.g., a classification model), one from unsupervised learning (e.g., a clustering model), and one from reinforcement learning. - For the supervised model, outline a strategy to evaluate its performance, including the choice of metrics (like accuracy, precision, recall, F1-score) and methods (like cross-validation, ROC curves).
# - For the unsupervised model, describe how you would assess the effectiveness of the model, considering techniques like silhouette score, elbow method, or cluster validation metrics.
# - For the reinforcement learning model, discuss how you would measure its success, considering aspects like cumulative reward, convergence, and exploration vs. exploitation balance.
# - Address the challenges and limitations of evaluating models in each category.

# %% [markdown]
# ### Guidance
# - Please write a separate paragraph for each of the three model categories.
# - In the supervised paragraph, describe your validation plan and list the metrics you will report in complete sentences.
# - In the unsupervised paragraph, explain how you would measure cluster quality or structure in complete sentences and mention any diagnostic plots.
# - In the reinforcement learning paragraph, describe how you would track cumulative reward, assess convergence, and balance exploration and exploitation using complete sentences.
# Conclude with one complete sentence per category that states a key evaluation challenge.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Supervised classification metrics template with placeholders.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score

# Replace these placeholders with your real outputs.
y_true = [0,1,1,0,1,0,0,1,0,1]
y_pred_proba = [0.1,0.7,0.8,0.2,0.6,0.3,0.4,0.9,0.2,0.85]
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Unsupervised clustering metrics template with synthetic data.

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

X, _ = make_blobs(n_samples=300, centers=3, random_state=42)
kmeans = KMeans(n_clusters=3, n_init="auto", random_state=42)
labels = kmeans.fit_predict(X)
sil = silhouette_score(X, labels)
print("Silhouette score (higher is better):", round(sil, 4))

print("Please explain in complete sentences when you would use the elbow method and how you would interpret it.")
# Out:
# Silhouette score (higher is better): 0.848
# Please explain in complete sentences when you would use the elbow method and how you would interpret it.

# %% [markdown]
# My Answer
# To Do: M
# odèle supervisé : Random Forest
#
# Métriques
#
# * Accuracy
# * Precision
# * Recall
# * F1-Score
# * AUC-ROC
#
# Méthodes d’évaluation
#
# * Validation croisée K-Fold
# * Matrice de confusion
# * Courbe ROC
#
# Défis
#
# * Déséquilibre des classes
# * Surapprentissage
# * Variabilité des données
#
# ⸻
#
# 2. Modèle non supervisé : K-Means
#
# Méthodes d’évaluation
#
# Score de silhouette
#
# Mesure la qualité de séparation entre les groupes.
#
# Méthode du coude
#
# Permet de déterminer le nombre optimal de clusters.
#
# Davies-Bouldin Index
#
# Évalue la compacité et la séparation des clusters.
#
# Défis
#
# Contrairement aux modèles supervisés, il n’existe pas de vérité terrain permettant de vérifier directement la qualité des regroupements.
#
# Le choix du nombre de clusters reste également complexe.
#
# ⸻
#
# 3. Modèle par renforcement : Q-Learning
#
# Mesures d’évaluation
#
# Récompense cumulative
#
# Somme totale des récompenses obtenues.
#
# Taux de réussite
#
# Pourcentage de missions accomplies avec succès.
#
# Temps de convergence
#
# Nombre d’épisodes nécessaires pour apprendre une stratégie efficace.
#
# Longueur moyenne du chemin
#
# Mesure l’efficacité de la solution trouvée.
#
# Défis
#
# * Équilibre entre exploration et exploitation.
# * Coût élevé de l’entraînement.
# * Variabilité des environnements.
#
# ⸻
#
# Conclusion
#
# Ce projet montre que le succès d’un système d’apprentissage automatique repose sur plusieurs étapes essentielles : une définition claire du problème, une collecte de données de qualité, une sélection rigoureuse des caractéristiques, un choix judicieux du modèle et une évaluation adaptée au contexte métier. Les modèles supervisés, non supervisés et par renforcement répondent chacun à des besoins différents et nécessitent des stratégies d’évaluation spécifiques. Une approche méthodique et bien justifiée permet d’obtenir des modèles robustes, performants et capables de fournir une réelle valeur ajoutée dans des situations réelles
