# %% [markdown]
# <a href="https://colab.research.google.com/github/demsaid400-cpu/DI-BOOTCAMP/blob/main/Week7/Day5/Daily_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
notebook_data = {
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {"id": "pR5d7nZQkS3e"},
      "source": ["# Daily Challenge: Precision Prompting for Control & Output Quality\n", "\n", "This notebook contains a full solution for designing, evaluating, and refining prompts with strict output control."]
    },
    {
      "cell_type": "markdown",
      "metadata": {"id": "7h4wT7nZkS3g"},
      "source": ["## Step 1 — Controlled Prompt"]
    },
    {
      "cell_type": "code",
      "metadata": {"id": "Wq5xT7nZkS3h"},
      "source": [
        "prompt_step1 = '''\n",
        "Rewrite the text below for an internal employee newsletter.\\n",
        "- Use a friendly, clear tone\\n",
        "- Convert into bullet points\\n",
        "- Paraphrase only (no direct quotes)\\n",
        "- Keep under 75 words\\n",
        "\\n",
        "Text:\\n",
        "Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.\\n",
        "'''\n",
        "print(prompt_step1)"
      ],
      "execution_count": None,
      "outputs": []
    },
    {
      "cell_type": "markdown",
      "metadata": {"id": "3q5xT7nZkS3i"},
      "source": ["## Step 2 — Example Output & Evaluation"]
    },
    {
      "cell_type": "code",
      "metadata": {"id": "Sr5xT7nZkS3j"},
      "source": [
        "output_step1 = \"- Always use approved secure VPN\\n- Avoid unsecured networks\\n- Do not use unprotected personal devices\"\n",
        "evaluation = {'Relevance': True, 'Clarity': True, 'Structure': True, 'Tone': 'Friendly', 'Length_OK': True, 'Factual_Accuracy': True}\n",
        "print(output_step1)"
      ],
      "execution_count": None,
      "outputs": []
    },
    {
      "cell_type": "markdown",
      "metadata": {"id": "Xr5xT7nZkS3k"},
      "source": ["## Step 3 — Hallucination Control Prompt"]
    },
    {
      "cell_type": "code",
      "metadata": {"id": "Dr5xT7nZkS3l"},
      "source": [
        "strict_prompt = '''\\nStrictly use provided content only. No new tools.\\n'''\n",
        "print(strict_prompt)"
      ],
      "execution_count": None,
      "outputs": []
    },
    {
      "cell_type": "markdown",
      "metadata": {"id": "Fr5xT7nZkS3m"},
      "source": ["## Step 4 — Simple Paraphrase for Interns"]
    },
    {
      "cell_type": "code",
      "metadata": {"id": "Gr5xT7nZkS3n"},
      "source": [
        "intern_prompt = '''\\nExplain for an intern:\\n- Simple language\\n- Max 4 bullets\\n- Supportive tone\\n'''\n",
        "print(intern_prompt)"
      ],
      "execution_count": None,
      "outputs": []
    },
    {
      "cell_type": "markdown",
      "metadata": {"id": "Hr5xT7nZkS3o"},
      "source": ["## Step 5 — Quote Extraction"]
    },
    {
      "cell_type": "code",
      "metadata": {"id": "Ir5xT7nZkS3p"},
      "source": [
        "quote_prompt = '''\\nExtract one exact sentence representing the core security rule.\\n'''\n",
        "print(quote_prompt)"
      ],
      "execution_count": None,
      "outputs": []
    },
    {
      "cell_type": "markdown",
      "metadata": {"id": "Kr5xT7nZkS3r"},
      "source": ["## Bonus: Automated Evaluation System"]
    },
    {
      "cell_type": "code",
      "metadata": {"id": "Lr5xT7nZkS3s"},
      "source": [
        "def evaluate_prompt_output(text):\\n",
        "    results = {'word_count': len(text.split()), 'has_bullets': '-' in text}\\n",
        "    return results\\n",
        "print(evaluate_prompt_output('Test'))"
      ],
      "execution_count": None,
      "outputs": []
    }
  ],
  "metadata": {
    "kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"},
    "language_info": {"name": "python"},
    "colab": {"provenance": [], "toc_visible": True},
    "accelerator": "GPU"
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
print("Notebook data updated with all challenge steps.")
# Out:
# Notebook data updated with all challenge steps.
