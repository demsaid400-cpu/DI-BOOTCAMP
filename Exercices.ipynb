# %% [markdown]
# <a href="https://colab.research.google.com/github/demsaid400-cpu/DI-BOOTCAMP/blob/main/Exercices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 1: Functions Exercises
#
# What is a module?
#
# A module is a file containing Python code (variables, functions, classes) that you can reuse in other programs. Every .py file you create is technically a module.Three ways to import a moduleimport math (imports the whole module)from math import sqrt (imports only a specific tool)import pandas as pd (imports a module with a shortcut name)Purpose of importingImporting lets you reuse code written by others or yourself without rewriting it. It keeps your projects organized, clean, and fast to build.Three examples when to use the random moduleShuffling a deck of cards in a digital game.Picking a random winner from a list of contest entries.Rolling a six-sided die to determine player movement in a board game.
#
# What is an ImportError?
#
# An ImportError occurs when Python cannot find or load the module or specific function you are trying to import. This usually happens because of typos, missing external packages, or wrong file paths.When using an OrderedDict is usefulAn OrderedDict is useful when you need a dictionary that strictly remembers the order keys were added, specifically if you need to reorder elements or support backward compatibility in Python versions older than 3.7.When using a defaultdict is usefulA defaultdict is useful when you want to avoid KeyError crashes. It automatically creates a default value (like an empty list or 0) whenever you try to access or modify a key that does not exist yet.Purpose of if __name__ == '__main__': passThis code checks whether the script is being run directly by the user or being imported into another file. If the script is run directly, the code inside this block executes. If the script is imported, this block is ignore
