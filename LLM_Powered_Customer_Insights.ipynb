# %% [markdown]
# # LLM Powered Customer Insights
#
# This repository: cleaned, public-friendly notebook version.
#
# If you want to see the original notebook (full outputs), open it on GitHub or NBViewer:
# - GitHub (original file name with quotes): https://github.com/demsaid400-cpu/DI-BOOTCAMP/blob/main/%22LLM_Powered_Customer_Insights%22.ipynb
# - NBViewer: https://nbviewer.org/github/demsaid400-cpu/DI-BOOTCAMP/blob/main/%22LLM_Powered_Customer_Insights%22.ipynb
# - Colab: https://colab.research.google.com/github/demsaid400-cpu/DI-BOOTCAMP/blob/main/%22LLM_Powered_Customer_Insights%22.ipynb
#
# ---
#
# Notes:
# - This notebook is a cleaned, minimal public-facing file added on branch `fix/rename-notebook`.
# - To finalize the rename and publish the HTML, review the branch and merge the PR I can open for you.
