# %% [markdown]
# <a href="https://colab.research.google.com/github/demsaid400-cpu/DI-BOOTCAMP/blob/main/Week7_Day5_Daily_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
notebook_data = {
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "pR5d7nZQkS3e"
      },
      "source": [
        "# Daily Challenge: Precision Prompting for Control & Output Quality\n",
        "\n",
        "This notebook contains a full solution for designing, evaluating, and refining prompts with strict output control."
      ]
    },
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "7h4wT7nZkS3g"
      },
      "source": [
        "## Step 1 — Controlled Prompt\n",
        "\n",
        "Rewrite the text below for an internal employee newsletter:\n",
        "- Friendly tone\n",
        "- Bullet points\n",
        "- Paraphrase only\n",
        "- Under 75 words"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {
        "id": "Wq5xT7nZkS3h"
      },
      "source": [
        "prompt_step1 = '''\n",
        "Rewrite the text below for an internal employee newsletter.\\n",
        "- Use a friendly, clear tone\\n",
        "- Convert into bullet points\\n",
        "- Paraphrase only (no direct quotes)\\n",
        "- Keep under 75 words\\n",
        "\\n",
        "Text:\\n",
        "Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used to access proprietary data or sensitive communications.\\n",
        "'''\n",
        "\n",
        "print(\"=== Step 1: Controlled Prompt ===\")\n",
        "print(prompt_step1)"
      ],
      "execution_count": None,
      "outputs": []
    },
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "3q5xT7nZkS3i"
      },
      "source": [
        "## Step 2 — Example Output & Evaluation"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {
        "id": "Sr5xT7nZkS3j"
      },
      "source": [
        "output_step1 = \"\"\"\n",
        "- Always use approved secure VPN for remote access\n",
        "- Avoid unsecured networks or connections\n",
        "- Do not use unprotected personal devices\n",
        "- Protect sensitive company data at all times\n",
        "\"\"\"\n",
        "\n",
        "evaluation = {\n",
        "    \"Relevance\": True,\n",
        "    \"Clarity\": True,\n",
        "    \"Structure\": True,\n",
        "    \"Tone\": \"Friendly and instructional\",\n",
        "    \"Length_OK\": True,\n",
        "    \"Factual_Accuracy\": True\n",
        "}\n",
        "\n",
        "print(\"=== Step 2: Output & Evaluation ===\")\n",
        "print(\"\\n📝 Generated Output:\")\n",
        "print(output_step1)\n",
        "\n",
        "print(\"\\n✅ Evaluation Results:\")\n",
        "for key, value in evaluation.items():\n",
        "    if isinstance(value, bool):\n",
        "        status = \"✅ PASS\" if value else \"❌ FAIL\"\n",
        "        print(f\"  {status}  {key}: {value}\")\n",
        "    else:\n",
        "        print(f\"  📌  {key}: {value}\")"
      ],
      "execution_count": None,
      "outputs": []
    },
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "Xr5xT7nZkS3k"
      },
      "source": [
        "## Step 3 — Hallucination Control Prompt"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {
        "id": "Dr5xT7nZkS3l"
      },
      "source": [
        "strict_prompt = '''\n",
        "Rewrite the text strictly using only the provided content.\\n",
        "- Do NOT add new tools, systems, or assumptions\\n",
        "- Do NOT infer missing information\\n",
        "- Bullet points only\\n",
        "- Under 75 words\\n",
        "\\n",
        "Text:\\n",
        "Employees must ensure that all remote access to internal systems is established via the approved secure VPN. Under no circumstances should unsecured connections or personal devices lacking endpoint protection be used.\\n",
        "'''\n",
        "\n",
        "print(\"=== Step 3: Hallucination Control Prompt ===\")\n",
        "print(strict_prompt)"
      ],
      "execution_count": None,
      "outputs": []
    }
  ],
  "metadata": {
    "kernelspec": {
      "display_name": "Python 3",
      "language": "python",
      "name": "python3"
    },
    "language_info": {
      "name": "python"
    },
    "colab": {
      "provenance": [],
      "toc_visible": True
    },
    "accelerator": "GPU"
  },
  "nbformat": 4,
  "nbformat_minor": 5
}
print("Notebook metadata corrected.")
# Out:
# Notebook metadata corrected.
