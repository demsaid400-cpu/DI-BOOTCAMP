# %% [markdown]
# <a href="https://colab.research.google.com/github/demsaid400-cpu/DI-BOOTCAMP/blob/main/Exercices_XP_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Afficher toutes les valeurs de la liste [1,2,3,4]
# (Une compréhension de liste génère None pour chaque print, on l'exécute directement)
[print(val) for val in [1, 2, 3, 4]]

# 2. Afficher toutes les valeurs multipliées par 20
[print(val * 20) for val in [1, 2, 3, 4]]

# 3. Retourner une liste avec seulement la première lettre de chaque prénom
# Résultat attendu : ["E", "T", "M"]
first_letters = [name[0] for name in ["Elie", "Tim", "Matt"]]

# 4. Retourner une liste avec uniquement les valeurs paires
# Résultat attendu : [2, 4, 6]
evens = [num for num in [1, 2, 3, 4, 5, 6] if num % 2 == 0]

# 5. Retourner l'intersection de deux listes
# Résultat attendu : [3, 4]
intersection = [val for val in [1, 2, 3, 4] if val in [3, 4, 5, 6]]

# 6. Retourner chaque mot inversé et en minuscules
# Résultat attendu : ['eile', 'mit', 'ttam']
reversed_lower = [word[::-1].lower() for word in ["Elie", "Tim", "Matt"]]

# 7. Retourner une liste avec les lettres présentes dans deux chaînes (intersection de caractères)
# Note : Pour éviter les doublons dans le même ordre, on filtre les lettres de la première chaîne
# Résultat attendu : ["i", "r", "t"]
char_intersection = [char for char in "first" if char in "third"]

# 8. Retourner les nombres entre 1 et 100 divisibles par 12
# Résultat attendu : [12, 24, 36, 48, 60, 72, 84, 96]
divisible_by_12 = [num for num in range(1, 101) if num % 12 == 0]

# 9. Supprimer toutes les voyelles de la chaîne "amazing"
# Résultat attendu : ['m', 'z', 'n', 'g']
no_vowels = [char for char in "amazing" if char not in "aeiou"]

# 10. Générer la liste imbriquée [[0, 1, 2], [0, 1, 2], [0, 1, 2]]
nested_list_3x3 = [[num for num in range(3)] for _ in range(3)]

# 11. Générer la grille imbriquée de 10 listes contenant les nombres de 0 à 9
nested_list_10x10 = [[num for num in range(10)] for _ in range(10)]
# Out:
# 1
# 2
# 3
# 4
# 20
# 40
# 60
# 80
